# %%
import pandas as pd
file_path = "movies_dataset/movies.csv"
rate_df = pd.read_csv(file_path)
df = pd.read_csv("final_tag.csv")
pd.set_option('display.max_colwidth', None)

# %%
rate_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                  movie_tag  \
# 0  00 Schneider - Jagd auf Nihil Baxter (1994)
# 1  1 Per Cent | Outlaws (Australia Movie 2017)
# 2                   10 Cloverfield Lane (2016)
# 3            10 Things I Hate About You (1999)
# 4                      The 10 Year Plan (2014)
#
#    amount_of_fan
# 0              1
# 1              2
# 2             13
# 3            134
# 4              5

# %%
df = df.drop("Unnamed: 0",axis=1)

# %%
df.head()
# Out:
#                                                                  movie_tag  \
# 0  00 Schneider - Jagd auf Nihil Baxter (1994)
# 1  1 Per Cent | Outlaws (Australia Movie 2017)
# 2                   10 Cloverfield Lane (2016)
# 3            10 Things I Hate About You (1999)
# 4                      The 10 Year Plan (2014)
#
#    amount_of_fan
# 0              1
# 1              2
# 2             13
# 3            134
# 4              5

# %%
rate_df.loc[rate_df["name"] == "Airplane!"]
# Out:
#         name rating   genre  year                      released  score  \
# 3  Airplane!     PG  Comedy  1980  July 2, 1980 (United States)    7.7
#
#       votes      director        writer         star        country  \
# 3  221000.0  Jim Abrahams  Jim Abrahams  Robert Hays  United States
#
#       budget       gross             company  runtime
# 3  3500000.0  83453539.0  Paramount Pictures     88.0

# %%
import re
df["movie_tag"].replace("\([A-Za-z\s0-9]*\)","", regex=True, inplace=True)

# %%
df["name"].replace("\A\s*","", regex=True, inplace=True)

# %%
df["name"].replace("\s*\Z","", regex=True, inplace=True)

# %%
df.head()
# Out:
#                                    name  amount_of_fan
# 0  00 Schneider - Jagd auf Nihil Baxter              1
# 1                  1 Per Cent | Outlaws              2
# 2                   10 Cloverfield Lane             13
# 3            10 Things I Hate About You            134
# 4                      The 10 Year Plan              5

# %%
df = df.rename(columns ={"movie_tag":"name" })

# %%
df.head()
# Out:
#                                    name  amount_of_fan
# 0  00 Schneider - Jagd auf Nihil Baxter              1
# 1                  1 Per Cent | Outlaws              2
# 2                   10 Cloverfield Lane             13
# 3            10 Things I Hate About You            134
# 4                      The 10 Year Plan              5

# %%
new_df = df.merge(rate_df,how="left")

# %%
new_df.isnull().sum()
# Out:
# name                0
# amount_of_fan       0
# rating           7003
# genre            6994
# year             6994
# released         6995
# score            6994
# votes            6994
# director         6994
# writer           6994
# star             6994
# country          6995
# budget           7594
# gross            7020
# company          6995
# runtime          6995
# dtype: int64

# %%
new_df.head()
# Out:
#                                    name  amount_of_fan rating   genre    year  \
# 0  00 Schneider - Jagd auf Nihil Baxter              1    NaN     NaN     NaN
# 1                  1 Per Cent | Outlaws              2    NaN     NaN     NaN
# 2                   10 Cloverfield Lane             13  PG-13  Action  2016.0
# 3            10 Things I Hate About You            134  PG-13  Comedy  1999.0
# 4                      The 10 Year Plan              5    NaN     NaN     NaN
#
#                          released  score     votes          director  \
# 0                             NaN    NaN       NaN               NaN
# 1                             NaN    NaN       NaN               NaN
# 2  March 11, 2016 (United States)    7.2  300000.0  Dan Trachtenberg
# 3  March 31, 1999 (United States)    7.3  309000.0        Gil Junger
# 4                             NaN    NaN       NaN               NaN
#
#            writer          star        country      budget        gross  \
# ...

# %%
rate_df.loc[rate_df["name"] == "10 Things I Hate About You"]
# Out:
#                             name rating   genre  year  \
# 3452  10 Things I Hate About You  PG-13  Comedy  1999
#
#                             released  score     votes    director  \
# 3452  March 31, 1999 (United States)    7.3  309000.0  Gil Junger
#
#               writer          star        country      budget       gross  \
# 3452  Karen McCullah  Heath Ledger  United States  30000000.0  53478579.0
#
#                   company  runtime
# 3452  Touchstone Pictures     97.0

# %%
df.loc[df["name"] == "1 Per Cent | Outlaws"]
# Out:
#                    name  amount_of_fan
# 1  1 Per Cent | Outlaws              2

# %%
df["name"].iloc[1]
# Out:
# '1 Per Cent | Outlaws'

# %%
df["name"]
# Out:
# 0                        00 Schneider - Jagd auf Nihil Baxter
# 1                                        1 Per Cent | Outlaws
# 2                                         10 Cloverfield Lane
# 3                                  10 Things I Hate About You
# 4                                            The 10 Year Plan
#                                  ...
# 10241        新蜀山劍俠 | Zu: The Warriors from the Magic Mountain
# 10242                                 最佳团伙 | Zuì Jiā Tuán Huǒ
# 10243                                                    Zulu
# 10244                                              Zuma Beach
# 10245    Zwischen Sommer und Herbst | Between Summer and Fall
# Name: name, Length: 10246, dtype: object

# %%
# Out:
# Empty DataFrame
# Columns: [name, rating, genre, year, released, score, votes, director, writer, star, country, budget, gross, company, runtime]
# Index: []

# %%
new_df.dropna(inplace=True)

# %%
new_df
# Out:
#                              name  amount_of_fan rating      genre    year  \
# 2             10 Cloverfield Lane             13  PG-13     Action  2016.0
# 3      10 Things I Hate About You            134  PG-13     Comedy  1999.0
# 13                 101 Dalmatians             52      G  Adventure  1996.0
# 14                 101 Dalmatians            172      G  Adventure  1996.0
# 18                     12 Monkeys              6      R    Mystery  1995.0
# ...                           ...            ...    ...        ...     ...
# 10412                      Zodiac             56      R      Crime  2007.0
# 10419                  Zombieland            214      R  Adventure  2009.0
# 10423                   Zoolander             32  PG-13     Comedy  2001.0
# 10424                        Zoom             19     PG     Action  2006.0
# 10425                    Zootopia           4600     PG  Animation  2016.0
#
# ...

# %%
df.head()
# Out:
#                                    name  amount_of_fan
# 0  00 Schneider - Jagd auf Nihil Baxter              1
# 1                  1 Per Cent | Outlaws              2
# 2                   10 Cloverfield Lane             13
# 3            10 Things I Hate About You            134
# 4                      The 10 Year Plan              5

# %%
df.to_csv("fina_tag2.csv")
