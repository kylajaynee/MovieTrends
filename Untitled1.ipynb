# %%
import pandas as pd
file_path = "merged.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#                          name rating      genre  year  \
# 0         10 Cloverfield Lane  PG-13     Action  2016
# 1  10 Things I Hate About You  PG-13     Comedy  1999
# 2              101 Dalmatians      G  Adventure  1996
# 3              101 Dalmatians      G  Adventure  1996
# 4                  12 Monkeys      R    Mystery  1995
#
#                             released  score   votes          director  \
# 0     March 11, 2016 (United States)    7.2  300000  Dan Trachtenberg
# 1     March 31, 1999 (United States)    7.3  309000        Gil Junger
# 2  November 27, 1996 (United States)    5.7  105000     Stephen Herek
# 3  November 27, 1996 (United States)    5.7  105000     Stephen Herek
# 4    January 5, 1996 (United States)    8.0  589000     Terry Gilliam
#
#            writer          star        country    budget      gross  \
# 0   Josh Campbell  John Goodman  United States  15000000  110216998
# 1  Karen McCullah  Heath Ledger  United States  30000000   53478579
# ...

# %%
df.count()
# Out:
# name             2702
# rating           2702
# genre            2702
# year             2702
# released         2702
# score            2702
# votes            2702
# director         2702
# writer           2702
# star             2702
# country          2702
# budget           2702
# gross            2702
# company          2702
# runtime          2702
# name-2           2702
# amount_of_fan    2702
# dtype: int64

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  2702.000000  2702.000000  2.702000e+03  2.702000e+03  2.702000e+03
# mean   2002.954848     6.562102  1.472956e+05  3.940804e+07  1.129589e+08
# std      10.138736     0.898573  1.981335e+05  4.068636e+07  1.702780e+08
# min    1980.000000     2.100000  2.430000e+02  7.000000e+03  2.554000e+03
# 25%    1996.000000     6.100000  3.500000e+04  1.200000e+07  1.707446e+07
# 50%    2004.000000     6.600000  8.100000e+04  2.500000e+07  5.208294e+07
# 75%    2011.000000     7.200000  1.790000e+05  5.000000e+07  1.419988e+08
# max    2020.000000     8.900000  2.100000e+06  3.000000e+08  2.847246e+09
#
#            runtime  amount_of_fan
# count  2702.000000    2702.000000
# mean    109.655440     311.988527
# std      19.448526    4393.517565
# min      69.000000       1.000000
# 25%      97.000000       2.000000
# 50%     106.000000       7.000000
# 75%     119.000000      28.000000
# ...

# %%
df.median()
# Out:
# C:\Users\seank\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# year                 2004.0
# score                   6.6
# votes               81000.0
# budget           25000000.0
# gross            52082940.5
# runtime               106.0
# amount_of_fan           7.0
# dtype: float64

# %%
df.skew(axis=0)
# Out:
# C:\Users\seank\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# year             -0.344694
# score            -0.684416
# votes             3.590501
# budget            2.027500
# gross             4.552267
# runtime           1.933555
# amount_of_fan    31.869177
# dtype: float64

# %%
new_df = df.loc[df["amount_of_fan"] < 20 ]

# %%
new_df.count()
# Out:
# name             1878
# rating           1878
# genre            1878
# year             1878
# released         1878
# score            1878
# votes            1878
# director         1878
# writer           1878
# star             1878
# country          1878
# budget           1878
# gross            1878
# company          1878
# runtime          1878
# name-2           1878
# amount_of_fan    1878
# dtype: int64

# %%
new_df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  1878.000000  1878.000000  1.878000e+03  1.878000e+03  1.878000e+03
# mean   2002.045261     6.433440  9.964858e+04  3.181564e+07  7.451660e+07
# std      10.088504     0.891169  1.259598e+05  3.120110e+07  1.023772e+08
# min    1980.000000     2.100000  2.430000e+02  7.000000e+03  5.073000e+03
# 25%    1995.000000     5.900000  2.800000e+04  1.050000e+07  1.330866e+07
# 50%    2003.000000     6.500000  6.000000e+04  2.200000e+07  3.877459e+07
# 75%    2010.000000     7.100000  1.190000e+05  4.000000e+07  9.693781e+07
# max    2020.000000     8.600000  1.300000e+06  2.500000e+08  1.281508e+09
#
#           runtime  amount_of_fan
# count  1878.00000    1878.000000
# mean    108.72098       5.245474
# std      19.08202       4.818708
# min      71.00000       1.000000
# 25%      96.00000       2.000000
# 50%     105.00000       3.000000
# 75%     118.00000       8.000000
# ...

# %%
new_df.head()
# Out:
#                   name rating      genre  year  \
# 0  10 Cloverfield Lane  PG-13     Action  2016
# 4           12 Monkeys      R    Mystery  1995
# 5            12 Rounds  PG-13     Action  2009
# 6     12 Years a Slave      R  Biography  2013
# 8                 1408  PG-13    Fantasy  2007
#
#                            released  score   votes          director  \
# 0    March 11, 2016 (United States)    7.2  300000  Dan Trachtenberg
# 4   January 5, 1996 (United States)    8.0  589000     Terry Gilliam
# 5    March 27, 2009 (United States)    5.6   28000      Renny Harlin
# 6  November 8, 2013 (United States)    8.1  657000     Steve McQueen
# 8     June 22, 2007 (United States)    6.8  260000   Mikael Håfström
#
#            writer              star        country    budget      gross  \
# 0   Josh Campbell      John Goodman  United States  15000000  110216998
# 4    Chris Marker      Bruce Willis  United States  29000001  168839459
# ...

# %%
x = df["amount_of_fan"]
y=df["score"]
# x = new_df["amount_of_fan"]
# y=new_df["score"]

# %%
y.isnull().sum()
# Out:
# 0

# %%
y.min()
# Out:
# 2.1

# %%
x
# Out:
# 0       13
# 4        6
# 5        5
# 6        7
# 8        8
#         ..
# 2693     3
# 2694    13
# 2695     6
# 2696     2
# 2700    19
# Name: amount_of_fan, Length: 1878, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_test, X_train,y_test,y_train = train_test_split(x,y,random_state=0)
X_train
# Out:
# 1431     3
# 179      1
# 300      7
# 2051    18
# 1755    15
#         ..
# 1855    13
# 2700    19
# 238      4
# 2204     2
# 2540     1
# Name: amount_of_fan, Length: 470, dtype: int64

# %%
import numpy as np
X_train = np.array(X_train).reshape(-1,1)
X_train
# Out:
# array([[ 3],
#        [ 1],
#        [ 7],
#        [18],
#        [15],
#        [ 1],
#        [ 2],
#        [ 8],
#        [ 1],
#        [ 3],
#        [ 3],
#        [ 2],
#        [ 2],
#        [ 6],
#        [ 9],
#        [ 2],
#        [ 2],
#        [ 1],
#        [ 2],
#        [ 5],
#        [ 1],
#        [ 5],
#        [14],
#        [ 2],
#        [11],
#        [ 2],
#        [ 1],
#        [ 4],
#        [ 8],
#        [ 1],
#        [ 1],
#        [ 4],
#        [ 9],
#        [ 2],
#        [ 2],
#        [16],
#        [ 9],
#        [ 4],
#        [ 1],
#        [13],
#        [ 6],
#        [ 4],
#        [ 1],
#        [ 3],
#        [ 6],
#        [ 6],
#        [ 4],
#        [ 1],
#        [ 5],
#        [ 1],
#        [ 3],
#        [12],
#        [ 2],
#        [19],
#        [ 5],
#        [18],
#        [ 1],
#        [ 4],
#        [11],
#        [ 5],
#        [ 1],
#        [19],
#        [ 2],
#        [13],
#        [ 1],
#        [ 3],
# ...

# %%
X_test = np.array(X_test).reshape(-1,1)
X_test
# Out:
# array([[1],
#        [2],
#        [4],
#        ...,
#        [2],
#        [3],
#        [6]], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scale_train = scaler.fit_transform(X_train)
X_scale_test = scaler.fit_transform(X_test)

# %%
X_scale_train
# Out:
# array([[-0.4463152 ],
#        [-0.84210414],
#        [ 0.3452627 ],
#        [ 2.52210191],
#        [ 1.92841849],
#        [-0.84210414],
#        [-0.64420967],
#        [ 0.54315717],
#        [-0.84210414],
#        [-0.4463152 ],
#        [-0.4463152 ],
#        [-0.64420967],
#        [-0.64420967],
#        [ 0.14736823],
#        [ 0.74105165],
#        [-0.64420967],
#        [-0.64420967],
#        [-0.84210414],
#        [-0.64420967],
#        [-0.05052625],
#        [-0.84210414],
#        [-0.05052625],
#        [ 1.73052401],
#        [-0.64420967],
#        [ 1.13684059],
#        [-0.64420967],
#        [-0.84210414],
#        [-0.24842072],
#        [ 0.54315717],
#        [-0.84210414],
#        [-0.84210414],
#        [-0.24842072],
#        [ 0.74105165],
#        [-0.64420967],
#        [-0.64420967],
#        [ 2.12631296],
#        [ 0.74105165],
#        [-0.24842072],
#        [-0.84210414],
#        [ 1.53262954],
#        [ 0.14736823],
# ...

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_scale_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([6.57441871, 6.65351827, 6.81171738, ..., 6.65351827, 6.73261783,
#        6.9699165 ])

# %%
y_test
# Out:
# 1463    7.5
# 2030    6.0
# 1947    6.2
# 689     5.6
# 33      6.8
#        ...
# 1195    6.2
# 1748    6.0
# 2375    6.1
# 795     6.5
# 968     6.8
# Name: score, Length: 1408, dtype: float64

# %%
y_testing = list(y_test)

# %%
y_testing
# Out:
# [7.5,
#  6.0,
#  6.2,
#  5.6,
#  6.8,
#  7.4,
#  5.3,
#  6.4,
#  5.9,
#  4.0,
#  7.1,
#  5.5,
#  6.9,
#  7.8,
#  6.3,
#  5.9,
#  6.4,
#  7.0,
#  7.5,
#  7.6,
#  6.1,
#  5.9,
#  6.6,
#  6.5,
#  6.6,
#  5.4,
#  5.9,
#  7.2,
#  7.0,
#  6.1,
#  7.1,
#  5.6,
#  6.6,
#  7.1,
#  6.2,
#  5.6,
#  6.4,
#  5.9,
#  6.1,
#  8.0,
#  6.5,
#  7.4,
#  5.9,
#  6.5,
#  7.0,
#  7.7,
#  6.3,
#  8.1,
#  6.4,
#  5.6,
#  6.0,
#  5.6,
#  7.4,
#  5.9,
#  6.5,
#  5.1,
#  2.9,
#  6.8,
#  5.6,
#  7.1,
#  5.4,
#  6.1,
#  6.9,
#  6.8,
#  7.2,
#  4.1,
#  4.9,
#  6.4,
#  5.8,
#  6.0,
#  7.4,
#  3.9,
#  7.3,
#  6.5,
#  6.5,
#  6.2,
#  6.8,
#  6.0,
#  7.2,
#  7.1,
#  7.1,
#  7.3,
#  6.7,
#  6.0,
#  6.2,
#  6.0,
#  6.2,
#  6.2,
#  7.0,
#  6.7,
#  7.3,
#  6.1,
#  4.2,
#  8.4,
#  7.0,
#  8.1,
#  6.6,
#  6.4,
#  7.7,
#  7.6,
#  5.1,
#  6.9,
#  7.5,
#  7.7,
#  7.2,
#  6.6,
#  6.6,
#  7.2,
#  6.7,
#  7.3,
#  6.2,
#  5.5,
#  7.1,
#  4.7,
#  4.4,
#  6.2,
#  5.6,
#  6.4,
#  7.7,
#  5.2,
#  7.1,
#  6.4,
#  4.6,
#  7.0,
#  5.5,
# ...

# %%
predict_df = pd.DataFrame(y_pred,y_testing)

# %%
predict_df.reset_index(inplace=True)

# %%
predict_df.head()
# Out:
#    index         0
# 0    7.5  6.574419
# 1    6.0  6.653518
# 2    6.2  6.811717
# 3    5.6  6.574419
# 4    6.8  7.444514

# %%
predict_df[0].min()
# Out:
# 6.574418707816063

# %%
import matplotlib.pyplot as plt
plt.scatter(X_scale_train,y_train)
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# -0.3700241355600684
